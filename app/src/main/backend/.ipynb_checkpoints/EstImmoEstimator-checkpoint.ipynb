# %%
import pandas as pd
import numpy as np
import glob
import os
import seaborn as sns
import matplotlib.pyplot as plt

# Définition du chemin vers les fichiers csv
path = "./transactions-ser"
# Récupération de tous les fichiers csv dans le répertoire spécifié
all_files = glob.glob(os.path.join(path, "*.csv"))

all_df = []
# Boucle sur chaque fichier csv pour en créer un dataframe et l'ajouter à la liste
for f in all_files:
    df = pd.read_csv(f, sep=';')
    df['file'] = f.split('/')[-1]
    all_df.append(df)

data = pd.concat(all_df, ignore_index=True)
merged_df = data.copy()
display(merged_df)
# Out:
#        id_mutation date_mutation  numero_disposition nature_mutation  \
# 0      2022-360375    2022-04-21                   1           Vente
# 1      2022-360375    2022-04-21                   1           Vente
# 2     2021-1180016    2021-05-10                   1           Vente
# 3     2021-1177880    2021-01-14                   1           Vente
# 4     2021-1177880    2021-01-14                   1           Vente
# ...            ...           ...                 ...             ...
# 2967  2019-1112209    2019-02-11                   1           Vente
# 2968  2018-1037104    2018-12-28                   1           Vente
# 2969  2018-1037104    2018-12-28                   1           Vente
# 2970  2018-1033451    2018-07-04                   1           Vente
# 2971  2018-1033549    2018-06-28                   1           Vente
#
#       valeur_fonciere  adresse_numero adresse_suffixe  \
# 0            260000.0            26.0            None
# 1            260000.0            26.0            None
# 2            160000.0            13.0            None
# 3            174000.0            21.0            None
# 4            174000.0            21.0            None
# ...               ...             ...             ...
# 2967          56460.0           620.0            None
# 2968        1000000.0          9010.0            None
# 2969        1000000.0          9010.0            None
# 2970         165600.0             NaN            None
# 2971         665000.0           165.0            None
#
#                  adresse_nom_voie adresse_code_voie code_postal  ...  \
# 0                     RUE DELILLE               582       76800  ...
# 1                     RUE DELILLE               582       76800  ...
# 2            RUE ALFRED DE MUSSET                40       76800  ...
# 3               RUE PAUL VERLAINE              1920       76800  ...
# 4               RUE PAUL VERLAINE              1920       76800  ...
# ...                           ...               ...         ...  ...
# 2967             RUE ISAAC NEWTON              1222       76800  ...
# 2968  CHE DE LA MARE AUX SANGSUES              1605       76800  ...
# 2969  CHE DE LA MARE AUX SANGSUES              1605       76800  ...
# 2970           AV DE L UNIVERSITE              2359       76800  ...
# 2971           RUE ETTORE BUGATTI              0815       76800  ...
#
#       nombre_pieces_principales code_nature_culture  nature_culture  \
# 0                           4.0                   S            sols
# 1                           0.0                   S            sols
# 2                           4.0                   S            sols
# 3                           4.0                   S            sols
# 4                           0.0                   S            sols
# ...                         ...                 ...             ...
# 2967                        0.0                   S            sols
# 2968                        3.0                   S            sols
# 2969                        0.0                   S            sols
# 2970                        NaN                   S            sols
# 2971                        0.0                   S            sols
#
#      code_nature_culture_speciale nature_culture_speciale surface_terrain  \
# 0                            None                    None           351.0
# 1                            None                    None           351.0
# 2                            None                    None           452.0
# 3                            None                    None           498.0
# 4                            None                    None           498.0
# ...                           ...                     ...             ...
# 2967                         None                    None         29103.0
# 2968                         None                    None          3973.0
# 2969                         None                    None          3973.0
# 2970                         None                    None          1465.0
# 2971                         None                    None          2112.0
#
#      longitude   latitude section_prefixe                              file
# 0     1.071855  49.401886           000AB  transactions-ser\76575_000AB.csv
# 1     1.071855  49.401886           000AB  transactions-ser\76575_000AB.csv
# 2     1.070963  49.402764           000AB  transactions-ser\76575_000AB.csv
# 3     1.070475  49.403622           000AB  transactions-ser\76575_000AB.csv
# 4     1.070475  49.403622           000AB  transactions-ser\76575_000AB.csv
# ...        ...        ...             ...                               ...
# 2967       NaN        NaN           000BW  transactions-ser\76575_000BW.csv
# 2968  1.059789  49.390736           000BW  transactions-ser\76575_000BW.csv
# 2969  1.059789  49.390736           000BW  transactions-ser\76575_000BW.csv
# 2970  1.076805  49.385296           000BW  transactions-ser\76575_000BW.csv
# 2971  1.060781  49.386334           000BW  transactions-ser\76575_000BW.csv
#
# [2972 rows x 42 columns]

# %%
#Calcule du pourcentage de valeur manquantes pour chaque colonnes
(merged_df.isna().sum()/merged_df.shape[0]).sort_values(ascending=True)
#missing_rate.sorted_values(ascending=True)
# Out:
# id_mutation                     0.000000
# nature_culture_speciale         0.000000
# code_nature_culture_speciale    0.000000
# nature_culture                  0.000000
# code_nature_culture             0.000000
# type_local                      0.000000
# code_type_local                 0.000000
# nombre_lots                     0.000000
# lot5_surface_carrez             0.000000
# lot5_numero                     0.000000
# lot4_surface_carrez             0.000000
# lot4_numero                     0.000000
# lot3_numero                     0.000000
# section_prefixe                 0.000000
# lot1_numero                     0.000000
# numero_volume                   0.000000
# lot2_numero                     0.000000
# id_parcelle                     0.000000
# date_mutation                   0.000000
# numero_disposition              0.000000
# nature_mutation                 0.000000
# ancien_id_parcelle              0.000000
# adresse_nom_voie                0.000000
# adresse_code_voie               0.000000
# code_postal                     0.000000
# adresse_suffixe                 0.000000
# nom_commune                     0.000000
# code_departement                0.000000
# ancien_code_commune             0.000000
# ancien_nom_commune              0.000000
# code_commune                    0.000000
# file                            0.000000
# longitude                       0.009085
# latitude                        0.009085
# valeur_fonciere                 0.016824
# surface_terrain                 0.153769
# lot3_surface_carrez             0.158143
# adresse_numero                  0.163190
# lot2_surface_carrez             0.238223
# nombre_pieces_principales       0.260767
# surface_reelle_bati             0.457268
# lot1_surface_carrez             0.563257
# dtype: float64

# %%
# Récupèrer que les lignes qui contient appartement et maison et les stocker dans 2 dataframe différents
df_app = merged_df[merged_df.type_local == 'Appartement']
df_mai = merged_df[merged_df.type_local == 'Maison']

# %%
# Remplacement des valeurs 'None' par NaN dans les deux dataframes
df_app=df_app.replace(to_replace='None', value=np.nan)
df_mai=df_mai.replace(to_replace='None', value=np.nan)

df_mai
# Out:
#        id_mutation date_mutation  numero_disposition nature_mutation  \
# 0      2022-360375    2022-04-21                   1           Vente
# 2     2021-1180016    2021-05-10                   1           Vente
# 3     2021-1177880    2021-01-14                   1           Vente
# 7     2019-1116084    2019-08-28                   1           Vente
# 8     2019-1114082    2019-06-14                   1           Vente
# ...            ...           ...                 ...             ...
# 2946   2017-544464    2017-09-27                   1           Vente
# 2948   2017-544392    2017-09-13                   1           Vente
# 2949   2017-544056    2017-09-08                   1           Vente
# 2950   2017-544305    2017-09-08                   1           Vente
# 2951   2017-544006    2017-09-01                   1           Vente
#
#       valeur_fonciere  adresse_numero adresse_suffixe  \
# 0            260000.0            26.0             NaN
# 2            160000.0            13.0             NaN
# 3            174000.0            21.0             NaN
# 7            180000.0            28.0             NaN
# 8            188000.0            38.0             NaN
# ...               ...             ...             ...
# 2946         225000.0             1.0             NaN
# 2948         145000.0            27.0             NaN
# 2949         262500.0             5.0             NaN
# 2950         130000.0            25.0             NaN
# 2951         189300.0            20.0             NaN
#
#                  adresse_nom_voie adresse_code_voie code_postal  ...  \
# 0                     RUE DELILLE               582       76800  ...
# 2            RUE ALFRED DE MUSSET                40       76800  ...
# 3               RUE PAUL VERLAINE              1920       76800  ...
# 7                     RUE DELILLE               582       76800  ...
# 8                     RUE DELILLE               582       76800  ...
# ...                           ...               ...         ...  ...
# 2946  RUE PIERRE JEAN DE BERANGER              1335       76800  ...
# 2948                RUE LAMARTINE              1420       76800  ...
# 2949  RUE PIERRE JEAN DE BERANGER              1335       76800  ...
# 2950                RUE LAMARTINE              1420       76800  ...
# 2951                RUE PAUL BERT              1870       76800  ...
#
#       nombre_pieces_principales code_nature_culture  nature_culture  \
# 0                           4.0                   S            sols
# 2                           4.0                   S            sols
# 3                           4.0                   S            sols
# 7                           5.0                   S            sols
# 8                           5.0                   S            sols
# ...                         ...                 ...             ...
# 2946                        6.0                   S            sols
# 2948                        5.0                   S            sols
# 2949                        5.0                   S            sols
# 2950                        4.0                   S            sols
# 2951                        4.0                   S            sols
#
#       code_nature_culture_speciale  nature_culture_speciale surface_terrain  \
# 0                              NaN                      NaN           351.0
# 2                              NaN                      NaN           452.0
# 3                              NaN                      NaN           498.0
# 7                              NaN                      NaN           348.0
# 8                              NaN                      NaN           377.0
# ...                            ...                      ...             ...
# 2946                           NaN                      NaN           389.0
# 2948                           NaN                      NaN           374.0
# 2949                           NaN                      NaN           434.0
# 2950                           NaN                      NaN           369.0
# 2951                           NaN                      NaN           354.0
#
#       longitude   latitude section_prefixe                              file
# 0      1.071855  49.401886           000AB  transactions-ser\76575_000AB.csv
# 2      1.070963  49.402764           000AB  transactions-ser\76575_000AB.csv
# 3      1.070475  49.403622           000AB  transactions-ser\76575_000AB.csv
# 7      1.071647  49.401956           000AB  transactions-ser\76575_000AB.csv
# 8      1.070502  49.402256           000AB  transactions-ser\76575_000AB.csv
# ...         ...        ...             ...                               ...
# 2946   1.069955  49.399447           000BV  transactions-ser\76575_000BV.csv
# 2948   1.072432  49.400659           000BV  transactions-ser\76575_000BV.csv
# 2949   1.069653  49.399310           000BV  transactions-ser\76575_000BV.csv
# 2950   1.072534  49.400600           000BV  transactions-ser\76575_000BV.csv
# 2951   1.071759  49.399769           000BV  transactions-ser\76575_000BV.csv
#
# [1077 rows x 42 columns]

# %%
# Suppression des colonnes entièrement vides dans le dataframe 'df_mai'
df_mai = df_mai.dropna(axis=1, how='all')

# %%
# Out:
# id_mutation                     0.000000
# date_mutation                   0.000000
# numero_disposition              0.000000
# nature_mutation                 0.000000
# valeur_fonciere                 0.000000
# adresse_numero                  0.000929
# adresse_suffixe                 0.959146
# adresse_nom_voie                0.000000
# adresse_code_voie               0.000000
# code_postal                     0.000000
# code_commune                    0.000000
# nom_commune                     0.000000
# code_departement                0.000000
# id_parcelle                     0.000000
# lot1_numero                     0.996286
# lot1_surface_carrez             0.997214
# nombre_lots                     0.000000
# code_type_local                 0.000000
# type_local                      0.000000
# surface_reelle_bati             0.000000
# nombre_pieces_principales       0.000000
# code_nature_culture             0.004643
# nature_culture                  0.004643
# code_nature_culture_speciale    0.981430
# nature_culture_speciale         0.981430
# surface_terrain                 0.004643
# longitude                       0.004643
# latitude                        0.004643
# section_prefixe                 0.000000
# file                            0.000000
# dtype: float64

# %%
#supprimer les colonnes ayant un mesure_rate > 0.8 ainsi que les colonnes qui n'affecterons pas nos résultats
df_mai = df_mai.drop(columns=['adresse_suffixe','lot1_numero', 'lot1_surface_carrez','nature_culture','code_type_local','nombre_lots','code_nature_culture_speciale','adresse_code_voie','code_postal','nature_culture_speciale','id_parcelle','type_local','nom_commune','adresse_nom_voie','id_mutation','file'
])

# %%
df_mai.corr()
# Out:
#                            numero_disposition  valeur_fonciere  \
# numero_disposition                   1.000000        -0.037937
# valeur_fonciere                     -0.037937         1.000000
# adresse_numero                      -0.005742        -0.020844
# code_commune                              NaN              NaN
# code_departement                          NaN              NaN
# surface_reelle_bati                 -0.034021         0.383937
# nombre_pieces_principales           -0.037978         0.207474
# surface_terrain                     -0.018578         0.199816
# longitude                            0.057567        -0.226475
# latitude                             0.019895         0.135552
#
#                            adresse_numero  code_commune  code_departement  \
# numero_disposition              -0.005742           NaN               NaN
# valeur_fonciere                 -0.020844           NaN               NaN
# adresse_numero                   1.000000           NaN               NaN
# code_commune                          NaN           NaN               NaN
# code_departement                      NaN           NaN               NaN
# surface_reelle_bati              0.031216           NaN               NaN
# nombre_pieces_principales        0.019974           NaN               NaN
# surface_terrain                  0.027402           NaN               NaN
# longitude                        0.057500           NaN               NaN
# latitude                        -0.129625           NaN               NaN
#
#                            surface_reelle_bati  nombre_pieces_principales  \
# numero_disposition                   -0.034021                  -0.037978
# valeur_fonciere                       0.383937                   0.207474
# adresse_numero                        0.031216                   0.019974
# code_commune                               NaN                        NaN
# code_departement                           NaN                        NaN
# surface_reelle_bati                   1.000000                   0.610393
# nombre_pieces_principales             0.610393                   1.000000
# surface_terrain                       0.014390                  -0.043220
# longitude                            -0.119481                  -0.130101
# latitude                              0.028603                   0.099038
#
#                            surface_terrain  longitude  latitude
# numero_disposition               -0.018578   0.057567  0.019895
# valeur_fonciere                   0.199816  -0.226475  0.135552
# adresse_numero                    0.027402   0.057500 -0.129625
# code_commune                           NaN        NaN       NaN
# code_departement                       NaN        NaN       NaN
# surface_reelle_bati               0.014390  -0.119481  0.028603
# nombre_pieces_principales        -0.043220  -0.130101  0.099038
# surface_terrain                   1.000000  -0.085828  0.089590
# longitude                        -0.085828   1.000000 -0.771464
# latitude                          0.089590  -0.771464  1.000000

# %%
df_mai = df_mai.drop(columns=['code_commune','code_departement'], axis=1)

# %%
#visualisation de la correlation pour mieux voir la relation entre les données
sns.heatmap(df_mai.corr(), annot=True)
df_mai.numero_disposition.unique()
# Out:
# array([1, 2, 3], dtype=int64)

# %%
#On commence l'encodage des variables qualitatifs

df_mai['date_mutation'] = pd.to_datetime(df_mai['date_mutation'])
df_mai['annee_mutation'] = df_mai['date_mutation'].dt.year

df_mai = df_mai.drop(['date_mutation'], axis=1)

# %%
#On doit transformer toutes les variables de type object
df_mai.dtypes
# Out:
# numero_disposition             int64
# nature_mutation               object
# valeur_fonciere              float64
# adresse_numero               float64
# surface_reelle_bati          float64
# nombre_pieces_principales    float64
# code_nature_culture           object
# surface_terrain              float64
# longitude                    float64
# latitude                     float64
# section_prefixe               object
# annee_mutation                 int64
# dtype: object

# %%
code = {'Vente': 0,
        'Adjudication': 1,
        'Vente en l\'état futur d\'achèvement': 2,
        'S':0,
        'AG':1,
        'J':2,
        'L':3,
        'AB':4,
        '1':1,
        '2':2,
        '000AB': 0, '000AC': 1, '000AD': 2, '000AE': 3, '000AH': 4, '000AI': 5, '000AK': 6, '000AO': 7, '000AP': 8,
        '000AR': 9, '000AS': 10, '000AT': 11, '000AV': 12, '000AW': 13, '000AX': 14, '000AY': 15, '000AZ': 16, '000BC': 17,
        '000BD': 18, '000BE': 19, '000BH': 20, '000BK': 21, '000BL': 22, '000BM': 23, '000BO': 24, '000BP': 25, '000BR': 26,
        '000BS': 27, '000BT': 28, '000BV': 29, '000BW': 30
       }

for col in df_mai.select_dtypes('object'):
    df_mai[col] = df_mai[col].map(code)

# %%
display(df_mai)
# Out:
#       numero_disposition  nature_mutation  valeur_fonciere  adresse_numero  \
# 0                      1                0         260000.0            26.0
# 2                      1                0         160000.0            13.0
# 3                      1                0         174000.0            21.0
# 7                      1                0         180000.0            28.0
# 8                      1                0         188000.0            38.0
# ...                  ...              ...              ...             ...
# 2946                   1                0         225000.0             1.0
# 2948                   1                0         145000.0            27.0
# 2949                   1                0         262500.0             5.0
# 2950                   1                0         130000.0            25.0
# 2951                   1                0         189300.0            20.0
#
#       surface_reelle_bati  nombre_pieces_principales  code_nature_culture  \
# 0                   129.0                        4.0                  0.0
# 2                    64.0                        4.0                  0.0
# 3                    64.0                        4.0                  0.0
# 7                   108.0                        5.0                  0.0
# 8                    74.0                        5.0                  0.0
# ...                   ...                        ...                  ...
# 2946                188.0                        6.0                  0.0
# 2948                 74.0                        5.0                  0.0
# 2949                102.0                        5.0                  0.0
# 2950                 64.0                        4.0                  0.0
# 2951                 80.0                        4.0                  0.0
#
#       surface_terrain  longitude   latitude  section_prefixe  annee_mutation
# 0               351.0   1.071855  49.401886                0            2022
# 2               452.0   1.070963  49.402764                0            2021
# 3               498.0   1.070475  49.403622                0            2021
# 7               348.0   1.071647  49.401956                0            2019
# 8               377.0   1.070502  49.402256                0            2019
# ...               ...        ...        ...              ...             ...
# 2946            389.0   1.069955  49.399447               29            2017
# 2948            374.0   1.072432  49.400659               29            2017
# 2949            434.0   1.069653  49.399310               29            2017
# 2950            369.0   1.072534  49.400600               29            2017
# 2951            354.0   1.071759  49.399769               29            2017
#
# [1077 rows x 12 columns]

# %%
plt.figure(figsize=(15, 10))
sns.heatmap(df_mai.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
#Suppression de quelques lignes qui affecteront la correlation entre les données
nan_counts = df_mai.isnull().sum()
print(nan_counts)

#df_mai = df_mai.drop(df_mai[df_mai['valeur_fonciere'] == 3060533.2].index)
# Out:
# numero_disposition           0
# nature_mutation              0
# valeur_fonciere              0
# adresse_numero               1
# surface_reelle_bati          0
# nombre_pieces_principales    0
# code_nature_culture          5
# surface_terrain              5
# longitude                    5
# latitude                     5
# section_prefixe              0
# annee_mutation               0
# dtype: int64

# %%
#df_mai = df_mai.drop(df_mai[df_mai['valeur_fonciere'] == 1.0].index)

# %%
#df_mai = df_mai.drop(df_mai[df_mai['nombre_pieces_principales'] == 22.0].index)
#df_mai = df_mai.dropna()
#df_mai = df_mai.drop(columns=['numero_disposition','adresse_numero','nature_mutation','annee_mutation'])

# %%
plt.figure(figsize=(15, 10))
sns.heatmap(df_mai.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
df_mai = df_mai.dropna(subset=['surface_terrain'])

# %%
df_mai = df_mai.drop(['code_nature_culture'], axis=1)

# %%
nan_counts = df_mai.isnull().sum()
print(nan_counts)
# Out:
# valeur_fonciere              0
# surface_reelle_bati          0
# nombre_pieces_principales    0
# surface_terrain              0
# longitude                    0
# latitude                     0
# section_prefixe              0
# dtype: int64

# %%
df_mai
# Out:
#       valeur_fonciere  surface_reelle_bati  nombre_pieces_principales  \
# 0            260000.0                129.0                        4.0
# 2            160000.0                 64.0                        4.0
# 3            174000.0                 64.0                        4.0
# 7            180000.0                108.0                        5.0
# 8            188000.0                 74.0                        5.0
# ...               ...                  ...                        ...
# 2946         225000.0                188.0                        6.0
# 2948         145000.0                 74.0                        5.0
# 2949         262500.0                102.0                        5.0
# 2950         130000.0                 64.0                        4.0
# 2951         189300.0                 80.0                        4.0
#
#       surface_terrain  longitude   latitude  section_prefixe
# 0               351.0   1.071855  49.401886                0
# 2               452.0   1.070963  49.402764                0
# 3               498.0   1.070475  49.403622                0
# 7               348.0   1.071647  49.401956                0
# 8               377.0   1.070502  49.402256                0
# ...               ...        ...        ...              ...
# 2946            389.0   1.069955  49.399447               29
# 2948            374.0   1.072432  49.400659               29
# 2949            434.0   1.069653  49.399310               29
# 2950            369.0   1.072534  49.400600               29
# 2951            354.0   1.071759  49.399769               29
#
# [1054 rows x 7 columns]

# %%
plt.scatter(df_mai.valeur_fonciere, df_mai.surface_reelle_bati)
sorted(df_mai.valeur_fonciere)
# Out:
# [7000.0,
#  7000.0,
#  15000.0,
#  31000.0,
#  36000.0,
#  36000.0,
#  37500.0,
#  40000.0,
#  41000.0,
#  42000.0,
#  42336.0,
#  43000.0,
#  44000.0,
#  45000.0,
#  45000.0,
#  47000.0,
#  47000.0,
#  50000.0,
#  50000.0,
#  50000.0,
#  50000.0,
#  50000.0,
#  50750.0,
#  52000.0,
#  53000.0,
#  53850.0,
#  55000.0,
#  55000.0,
#  55135.0,
#  55750.0,
#  57000.0,
#  58750.0,
#  59950.0,
#  60000.0,
#  60000.0,
#  60000.0,
#  61000.0,
#  62000.0,
#  63000.0,
#  63500.0,
#  65000.0,
#  65000.0,
#  65000.0,
#  66000.0,
#  66000.0,
#  69000.0,
#  70000.0,
#  70000.0,
#  70000.0,
#  70000.0,
#  70000.0,
#  70000.0,
#  70500.0,
#  70500.0,
#  71000.0,
#  71000.0,
#  71300.0,
#  73000.0,
#  73000.0,
#  73800.0,
#  74650.0,
#  75000.0,
#  75000.0,
#  75300.0,
#  76000.0,
#  76000.0,
#  76000.0,
#  76500.0,
#  76500.0,
#  77500.0,
#  77621.0,
#  78000.0,
#  79100.0,
#  80000.0,
#  80000.0,
#  80000.0,
#  80000.0,
#  80000.0,
#  80000.0,
#  81000.0,
#  81000.0,
#  82812.5,
#  83000.0,
#  84500.0,
#  85000.0,
#  85000.0,
#  85000.0,
#  85000.0,
#  86000.0,
#  87000.0,
#  87100.0,
#  87642.5,
#  88000.0,
#  88000.0,
#  88000.0,
#  88650.0,
#  90000.0,
#  90000.0,
#  90000.0,
#  90000.0,
#  90000.0,
#  90000.0,
#  90000.0,
#  90000.0,
#  90000.0,
#  91000.0,
#  91500.0,
#  91800.0,
#  92000.0,
#  92000.0,
#  92000.0,
#  93000.0,
#  94300.0,
#  94500.0,
#  95000.0,
#  95000.0,
#  95000.0,
#  95000.0,
#  95000.0,
#  96000.0,
#  96000.0,
#  96000.0,
#  97000.0,
#  97500.0,
#  98000.0,
#  98000.0,
#  98000.0,
#  99000.0,
#  100000.0,
#  100000.0,
#  100000.0,
#  100000.0,
#  100000.0,
#  100000.0,
#  100000.0,
#  100000.0,
#  100000.0,
#  100000.0,
#  100000.0,
#  100000.0,
#  100000.0,
#  100000.0,
#  100000.0,
#  100000.0,
#  100100.0,
#  100100.0,
#  101000.0,
#  101000.0,
#  101750.0,
#  102000.0,
#  103000.0,
#  103000.0,
#  103000.0,
#  103000.0,
#  103100.0,
#  104000.0,
#  104000.0,
#  104650.0,
#  104900.0,
#  105000.0,
#  105000.0,
#  105000.0,
#  105000.0,
#  105000.0,
#  105000.0,
#  105000.0,
#  105000.0,
#  105000.0,
#  106000.0,
#  106400.0,
#  107000.0,
#  107000.0,
#  107200.0,
#  107500.0,
#  108000.0,
#  109500.0,
#  110000.0,
#  110000.0,
#  110000.0,
#  110000.0,
#  110000.0,
#  110000.0,
#  110000.0,
#  110000.0,
#  110000.0,
#  110000.0,
#  110000.0,
#  110000.0,
#  110000.0,
#  110000.0,
#  110000.0,
#  111000.0,
#  111000.0,
#  111000.0,
#  111000.0,
#  111350.0,
#  111900.0,
#  112000.0,
#  112000.0,
#  113000.0,
#  113000.0,
#  113500.0,
#  114000.0,
#  114500.0,
#  114900.0,
#  115000.0,
#  115000.0,
#  115000.0,
#  115000.0,
#  115000.0,
#  115000.0,
#  115000.0,
#  115000.0,
#  115550.0,
#  116000.0,
#  116000.0,
#  116000.0,
#  116500.0,
#  116650.0,
#  117000.0,
#  117500.0,
#  117500.0,
#  117500.0,
#  117700.0,
#  118000.0,
#  118000.0,
#  118000.0,
#  118000.0,
#  118500.0,
#  119000.0,
#  119000.0,
#  119000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  120000.0,
#  120100.0,
#  120900.0,
#  121000.0,
#  121000.0,
#  121190.0,
#  121350.0,
#  122000.0,
#  123000.0,
#  123000.0,
#  123000.0,
#  123000.0,
#  123550.0,
#  124500.0,
#  124600.0,
#  124900.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125000.0,
#  125700.0,
#  126000.0,
#  126000.0,
#  126000.0,
#  126000.0,
#  126000.0,
#  127000.0,
#  127000.0,
#  127000.0,
#  127000.0,
#  127000.0,
#  127000.0,
#  127000.0,
#  127500.0,
#  128000.0,
#  128000.0,
#  128000.0,
#  128500.0,
#  129000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130000.0,
#  130500.0,
#  131000.0,
#  131000.0,
#  131000.0,
#  131000.0,
#  131000.0,
#  131775.0,
#  132000.0,
#  132000.0,
#  132500.0,
#  132600.0,
#  132800.0,
#  133000.0,
#  133000.0,
#  134000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135000.0,
#  135800.0,
#  136000.0,
#  136000.0,
#  136000.0,
#  136000.0,
#  136000.0,
#  136200.0,
#  136500.0,
#  136900.0,
#  137000.0,
#  137000.0,
#  137000.0,
#  137000.0,
#  137100.0,
#  138000.0,
#  138000.0,
#  138000.0,
#  138000.0,
#  138000.0,
#  139000.0,
#  139500.0,
#  139500.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  140000.0,
#  141000.0,
#  141000.0,
#  141000.0,
#  142000.0,
#  142000.0,
#  142000.0,
#  142000.0,
#  142000.0,
#  143000.0,
#  143200.0,
#  144200.0,
#  144800.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  145000.0,
#  146000.0,
#  146000.0,
#  146500.0,
#  146500.0,
#  147000.0,
#  147000.0,
#  147000.0,
#  147000.0,
#  147000.0,
#  147000.0,
#  147000.0,
#  147000.0,
#  147000.0,
#  147000.0,
#  147000.0,
#  147500.0,
#  147600.0,
#  147930.0,
#  147950.0,
#  148000.0,
#  148000.0,
#  148000.0,
#  148000.0,
#  148400.0,
#  148500.0,
#  148500.0,
#  148900.0,
#  149000.0,
#  149500.0,
#  149800.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150000.0,
#  150300.0,
#  150500.0,
#  151000.0,
#  151100.0,
#  151600.0,
#  151700.0,
#  152000.0,
#  152000.0,
#  152000.0,
#  152000.0,
#  152000.0,
#  152000.0,
#  152000.0,
#  152000.0,
#  153000.0,
#  153000.0,
#  153000.0,
#  153600.0,
#  153800.0,
#  154000.0,
#  154000.0,
#  154000.0,
#  154000.0,
#  155000.0,
#  155000.0,
#  155000.0,
#  155000.0,
#  155000.0,
#  155000.0,
#  155000.0,
#  155500.0,
#  155500.0,
#  155500.0,
#  155800.0,
#  155880.0,
#  156000.0,
#  156000.0,
#  156000.0,
#  156000.0,
#  156000.0,
#  156300.0,
#  156500.0,
#  156600.0,
#  156650.0,
#  156900.0,
#  157000.0,
#  157000.0,
#  157000.0,
#  157000.0,
#  157000.0,
#  157010.0,
#  157100.0,
#  157500.0,
#  157700.0,
#  157930.0,
#  158000.0,
#  158000.0,
#  158000.0,
#  158000.0,
#  158000.0,
#  158000.0,
#  158100.0,
#  158500.0,
#  158500.0,
#  158500.0,
#  158500.0,
#  158500.0,
#  158690.0,
#  158750.0,
#  159000.0,
#  159000.0,
#  159000.0,
#  159000.0,
#  159000.0,
#  159000.0,
#  159500.0,
#  159700.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160000.0,
#  160400.0,
#  160500.0,
#  160600.0,
#  161000.0,
#  161000.0,
#  161000.0,
#  161000.0,
#  161500.0,
#  161500.0,
#  161500.0,
#  161800.0,
#  162000.0,
#  162000.0,
#  162000.0,
#  162000.0,
#  162500.0,
#  162800.0,
#  163000.0,
#  163000.0,
#  163000.0,
#  163000.0,
#  164000.0,
#  164000.0,
#  164180.0,
#  164950.0,
#  165000.0,
#  165000.0,
#  165000.0,
#  165000.0,
#  165000.0,
#  165000.0,
#  165000.0,
#  165000.0,
#  165000.0,
#  165000.0,
#  165000.0,
#  165500.0,
#  165500.0,
#  166000.0,
#  166000.0,
#  166500.0,
#  166800.0,
#  167000.0,
#  167000.0,
#  167000.0,
#  167000.0,
#  167230.0,
#  168000.0,
#  168000.0,
#  168000.0,
#  168000.0,
#  168000.0,
#  168000.0,
#  168100.0,
#  168450.0,
#  169000.0,
#  169000.0,
#  169000.0,
#  169500.0,
#  169550.0,
#  170000.0,
#  170000.0,
#  170000.0,
#  170000.0,
#  170000.0,
#  170000.0,
#  170000.0,
#  170000.0,
#  170000.0,
#  170000.0,
#  170000.0,
#  170000.0,
#  170000.0,
#  170000.0,
#  170000.0,
#  170000.0,
#  170100.0,
#  170900.0,
#  171000.0,
#  171000.0,
#  171000.0,
#  171000.0,
#  171000.0,
#  171000.0,
#  171400.0,
#  171650.0,
#  171900.0,
#  172000.0,
#  172000.0,
#  172000.0,
#  172000.0,
#  172000.0,
#  172450.0,
#  172500.0,
#  173000.0,
#  173000.0,
#  173000.0,
#  173000.0,
#  173000.0,
#  173000.0,
#  173000.0,
#  173400.0,
#  173500.0,
#  174000.0,
#  174000.0,
#  174000.0,
#  174000.0,
#  174000.0,
#  174000.0,
#  174000.0,
#  174000.0,
#  175000.0,
#  175000.0,
#  175000.0,
#  175000.0,
#  175500.0,
#  175500.0,
#  175500.0,
#  175900.0,
#  176000.0,
#  176000.0,
#  176000.0,
#  176000.0,
#  176000.0,
#  176000.0,
#  176100.0,
#  176700.0,
#  176800.0,
#  176900.0,
#  177000.0,
#  177000.0,
#  177000.0,
#  177000.0,
#  177000.0,
#  177500.0,
#  178000.0,
#  178000.0,
#  178000.0,
#  178000.0,
#  178000.0,
#  178190.0,
#  178400.0,
#  178500.0,
#  178900.0,
#  178900.0,
#  178900.0,
#  179000.0,
#  179000.0,
#  179000.0,
#  179300.0,
#  179550.0,
#  179778.0,
#  179950.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180000.0,
#  180229.0,
#  180229.0,
#  180500.0,
#  180500.0,
#  180592.06,
#  180800.0,
#  181000.0,
#  181000.0,
#  181000.0,
#  181000.0,
#  181300.0,
#  181400.0,
#  181500.0,
#  181500.0,
#  181700.0,
#  181950.0,
#  182000.0,
#  182000.0,
#  182000.0,
#  182000.0,
#  182300.0,
#  182400.0,
#  182400.0,
#  182400.0,
#  182500.0,
#  182500.0,
#  182700.0,
#  182800.0,
#  183000.0,
#  183000.0,
#  183000.0,
#  183700.0,
#  184000.0,
#  184100.0,
#  184500.0,
#  185000.0,
#  185000.0,
#  185000.0,
#  185000.0,
#  185000.0,
#  185000.0,
#  185000.0,
#  185500.0,
#  185500.0,
#  185500.0,
#  185900.0,
#  186000.0,
#  186000.0,
#  186000.0,
#  186000.0,
#  186000.0,
#  187000.0,
#  187000.0,
#  187530.0,
#  187900.0,
#  188000.0,
#  188000.0,
#  188000.0,
#  188000.0,
#  188000.0,
#  188276.83,
#  188600.0,
#  188700.0,
#  189000.0,
#  189300.0,
#  189500.0,
#  190000.0,
#  190000.0,
#  190000.0,
#  190000.0,
#  190000.0,
#  190000.0,
#  190000.0,
#  190000.0,
#  190000.0,
#  190000.0,
#  190000.0,
#  190000.0,
#  190000.0,
#  190200.0,
#  190550.0,
#  192000.0,
#  192000.0,
#  192000.0,
#  192550.0,
#  193950.0,
#  194000.0,
#  194000.0,
#  194500.0,
#  195000.0,
#  195000.0,
#  195000.0,
#  195500.0,
#  196000.0,
#  196000.0,
#  196000.0,
#  196500.0,
#  196800.0,
#  197300.0,
#  197500.0,
#  198000.0,
#  198000.0,
#  198000.0,
#  198000.0,
#  199000.0,
#  199000.0,
#  199000.0,
#  199900.0,
#  200000.0,
#  200000.0,
#  200000.0,
#  200000.0,
#  200000.0,
#  200000.0,
#  200000.0,
#  200000.0,
#  200000.0,
#  200000.0,
#  200000.0,
#  200000.0,
#  200000.0,
#  200800.0,
#  202000.0,
#  202000.0,
#  202000.0,
#  202500.0,
#  202500.0,
#  203000.0,
#  203000.0,
#  203000.0,
#  203000.0,
#  204000.0,
#  204000.0,
#  204050.0,
#  204400.0,
#  204500.0,
#  205000.0,
#  205000.0,
#  205000.0,
#  205050.0,
#  206000.0,
#  207000.0,
#  207500.0,
#  207500.0,
#  207650.0,
#  208000.0,
#  209000.0,
#  209000.0,
#  209500.0,
#  209700.0,
#  210000.0,
#  210000.0,
#  210000.0,
#  210000.0,
#  210000.0,
#  210100.0,
#  211000.0,
#  211550.0,
#  212000.0,
#  212000.0,
#  212400.0,
#  212700.0,
#  213100.0,
#  213100.0,
#  213150.0,
#  213600.0,
#  213975.0,
#  214000.0,
#  214000.0,
#  215000.0,
#  215000.0,
#  215000.0,
#  215000.0,
#  215000.0,
#  215000.0,
#  215000.0,
#  215000.0,
#  215000.0,
#  215000.0,
#  215000.0,
#  215100.0,
#  215100.0,
#  216000.0,
#  216000.0,
#  216500.0,
#  216975.0,
#  217000.0,
#  217300.0,
#  217500.0,
#  218000.0,
#  218000.0,
#  218000.0,
#  218350.0,
#  219000.0,
#  219000.0,
#  219350.0,
#  220000.0,
#  220000.0,
#  220000.0,
#  220000.0,
#  220000.0,
#  220000.0,
#  220000.0,
#  220000.0,
#  221650.0,
#  221700.0,
#  222000.0,
#  222900.0,
#  223000.0,
#  223150.0,
#  224000.0,
#  224100.0,
#  224100.0,
#  224100.0,
#  225000.0,
#  225000.0,
#  225000.0,
#  225000.0,
#  225000.0,
#  226000.0,
#  226000.0,
#  226900.0,
#  227000.0,
#  228100.0,
#  228200.0,
#  228500.0,
#  230000.0,
#  230000.0,
#  230000.0,
#  230000.0,
#  230000.0,
#  231000.0,
#  231000.0,
#  231000.0,
#  231800.0,
#  231850.0,
#  231940.0,
#  232500.0,
#  232800.0,
#  233000.0,
#  233000.0,
#  233000.0,
#  233000.0,
#  233000.0,
#  233500.0,
#  233500.0,
#  234700.0,
#  235000.0,
#  235000.0,
#  235000.0,
#  235000.0,
#  235000.0,
#  235200.0,
#  235700.0,
#  235900.0,
#  237000.0,
#  237000.0,
#  239000.0,
#  240000.0,
#  240000.0,
#  241000.0,
#  242000.0,
#  242600.0,
#  246000.0,
#  246000.0,
#  246000.0,
#  247000.0,
#  248000.0,
#  248000.0,
#  248000.0,
#  248500.0,
#  249900.0,
#  250000.0,
#  250000.0,
#  250000.0,
#  250000.0,
#  251000.0,
#  251500.0,
#  252000.0,
#  252000.0,
#  252300.0,
#  253000.0,
#  253500.0,
#  253650.0,
#  254050.0,
#  255000.0,
#  255000.0,
#  257000.0,
#  257150.0,
#  258000.0,
#  259000.0,
#  259000.0,
#  260000.0,
#  260000.0,
#  260000.0,
#  260400.0,
#  261000.0,
#  262500.0,
#  263000.0,
#  263000.0,
#  266000.0,
#  267500.0,
#  268000.0,
#  270000.0,
#  275000.0,
#  275000.0,
#  275000.0,
#  275000.0,
#  276400.0,
#  ...]

# %%
sns.heatmap(df_mai.corr(), annot=True)
df_mai.hist()
# Out:
# array([[<AxesSubplot:title={'center':'valeur_fonciere'}>,
#         <AxesSubplot:title={'center':'surface_reelle_bati'}>,
#         <AxesSubplot:title={'center':'nombre_pieces_principales'}>],
#        [<AxesSubplot:title={'center':'surface_terrain'}>,
#         <AxesSubplot:title={'center':'longitude'}>,
#         <AxesSubplot:title={'center':'latitude'}>],
#        [<AxesSubplot:title={'center':'section_prefixe'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
df_mai = df_mai.dropna()
df_mai
# Out:
#       valeur_fonciere  surface_reelle_bati  nombre_pieces_principales  \
# 0            260000.0                129.0                        4.0
# 2            160000.0                 64.0                        4.0
# 3            174000.0                 64.0                        4.0
# 7            180000.0                108.0                        5.0
# 8            188000.0                 74.0                        5.0
# ...               ...                  ...                        ...
# 2946         225000.0                188.0                        6.0
# 2948         145000.0                 74.0                        5.0
# 2949         262500.0                102.0                        5.0
# 2950         130000.0                 64.0                        4.0
# 2951         189300.0                 80.0                        4.0
#
#       surface_terrain  longitude   latitude  section_prefixe
# 0               351.0   1.071855  49.401886                0
# 2               452.0   1.070963  49.402764                0
# 3               498.0   1.070475  49.403622                0
# 7               348.0   1.071647  49.401956                0
# 8               377.0   1.070502  49.402256                0
# ...               ...        ...        ...              ...
# 2946            389.0   1.069955  49.399447               29
# 2948            374.0   1.072432  49.400659               29
# 2949            434.0   1.069653  49.399310               29
# 2950            369.0   1.072534  49.400600               29
# 2951            354.0   1.071759  49.399769               29
#
# [1054 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline  import make_pipeline
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score

X = df_mai.drop(columns=['valeur_fonciere','longitude','latitude'], axis=1)
print(X)
y = df_mai['valeur_fonciere']
plt.hist(y)
plt.show()

#poly_features = PolynomialFeatures(degree=degree, include_bias = False)


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Create a polynomial transformer
poly = PolynomialFeatures(degree=3, interaction_only=True)

# Transform the training and test data
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)
#poly_features = PolynomialFeatures(degree=degree, include_bias = False)
reg = LinearRegression()
#X_poly = poly_features.fit_transform(X_train)
#X_poly_test = poly_features.fit_transform(X_test)


reg.fit(X_train_poly,y_train)
# Out:
#        id_mutation date_mutation  numero_disposition nature_mutation  \
# 0      2022-360375    2022-04-21                   1           Vente
# 2     2021-1180016    2021-05-10                   1           Vente
# 3     2021-1177880    2021-01-14                   1           Vente
# 7     2019-1116084    2019-08-28                   1           Vente
# 8     2019-1114082    2019-06-14                   1           Vente
# ...            ...           ...                 ...             ...
# 2946   2017-544464    2017-09-27                   1           Vente
# 2948   2017-544392    2017-09-13                   1           Vente
# 2949   2017-544056    2017-09-08                   1           Vente
# 2950   2017-544305    2017-09-08                   1           Vente
# 2951   2017-544006    2017-09-01                   1           Vente
#
#       adresse_numero adresse_suffixe             adresse_nom_voie  \
# 0               26.0             NaN                  RUE DELILLE
# 2               13.0             NaN         RUE ALFRED DE MUSSET
# 3               21.0             NaN            RUE PAUL VERLAINE
# 7               28.0             NaN                  RUE DELILLE
# 8               38.0             NaN                  RUE DELILLE
# ...              ...             ...                          ...
# 2946             1.0             NaN  RUE PIERRE JEAN DE BERANGER
# 2948            27.0             NaN                RUE LAMARTINE
# 2949             5.0             NaN  RUE PIERRE JEAN DE BERANGER
# 2950            25.0             NaN                RUE LAMARTINE
# 2951            20.0             NaN                RUE PAUL BERT
#
#      adresse_code_voie code_postal  code_commune  ... type_local  \
# 0                  582       76800         76575  ...     Maison
# 2                   40       76800         76575  ...     Maison
# 3                 1920       76800         76575  ...     Maison
# 7                  582       76800         76575  ...     Maison
# 8                  582       76800         76575  ...     Maison
# ...                ...         ...           ...  ...        ...
# 2946              1335       76800         76575  ...     Maison
# 2948              1420       76800         76575  ...     Maison
# 2949              1335       76800         76575  ...     Maison
# 2950              1420       76800         76575  ...     Maison
# 2951              1870       76800         76575  ...     Maison
#
#       surface_reelle_bati  nombre_pieces_principales  code_nature_culture  \
# 0                   129.0                        4.0                    S
# 2                    64.0                        4.0                    S
# 3                    64.0                        4.0                    S
# 7                   108.0                        5.0                    S
# 8                    74.0                        5.0                    S
# ...                   ...                        ...                  ...
# 2946                188.0                        6.0                    S
# 2948                 74.0                        5.0                    S
# 2949                102.0                        5.0                    S
# 2950                 64.0                        4.0                    S
# 2951                 80.0                        4.0                    S
#
#      nature_culture  code_nature_culture_speciale  nature_culture_speciale  \
# 0              sols                           NaN                      NaN
# 2              sols                           NaN                      NaN
# 3              sols                           NaN                      NaN
# 7              sols                           NaN                      NaN
# 8              sols                           NaN                      NaN
# ...             ...                           ...                      ...
# 2946           sols                           NaN                      NaN
# 2948           sols                           NaN                      NaN
# 2949           sols                           NaN                      NaN
# 2950           sols                           NaN                      NaN
# 2951           sols                           NaN                      NaN
#
#      surface_terrain  section_prefixe                              file
# 0              351.0            000AB  transactions-ser\76575_000AB.csv
# 2              452.0            000AB  transactions-ser\76575_000AB.csv
# 3              498.0            000AB  transactions-ser\76575_000AB.csv
# 7              348.0            000AB  transactions-ser\76575_000AB.csv
# 8              377.0            000AB  transactions-ser\76575_000AB.csv
# ...              ...              ...                               ...
# 2946           389.0            000BV  transactions-ser\76575_000BV.csv
# 2948           374.0            000BV  transactions-ser\76575_000BV.csv
# 2949           434.0            000BV  transactions-ser\76575_000BV.csv
# 2950           369.0            000BV  transactions-ser\76575_000BV.csv
# 2951           354.0            000BV  transactions-ser\76575_000BV.csv
#
# [1077 rows x 39 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [366], in <cell line: 22>()
#      19 poly = PolynomialFeatures(degree=3, interaction_only=True)
#      21 # Transform the training and test data
# ---> 22 X_train_poly = poly.fit_transform(X_train)
#      23 X_test_poly = poly.transform(X_test)
#      24 #poly_features = PolynomialFeatures(degree=degree, include_bias = False)
#
# File ~\anaconda3\lib\site-packages\sklearn\base.py:852, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     848 # non-optimized default implementation; override when a better
#     849 # method is possible for a given clustering algorithm
#     850 if y is None:
#     851     # fit method of arity 1 (unsupervised transformation)
# --> 852     return self.fit(X, **fit_params).transform(X)
#     853 else:
#     854     # fit method of arity 2 (supervised transformation)
#     855     return self.fit(X, y, **fit_params).transform(X)
#
# File ~\anaconda3\lib\site-packages\sklearn\preprocessing\_polynomial.py:287, in PolynomialFeatures.fit(self, X, y)
#     270 def fit(self, X, y=None):
#     271     """
#     272     Compute number of output features.
#     273
#    (...)
#     285         Fitted transformer.
#     286     """
# --> 287     _, n_features = self._validate_data(X, accept_sparse=True).shape
#     289     if isinstance(self.degree, numbers.Integral):
#     290         if self.degree < 0:
#
# File ~\anaconda3\lib\site-packages\sklearn\base.py:566, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     564     raise ValueError("Validation should be done on X, y or both.")
#     565 elif not no_val_X and no_val_y:
# --> 566     X = check_array(X, **check_params)
#     567     out = X
#     568 elif no_val_X and not no_val_y:
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\validation.py:746, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     744         array = array.astype(dtype, casting="unsafe", copy=False)
#     745     else:
# --> 746         array = np.asarray(array, order=order, dtype=dtype)
#     747 except ComplexWarning as complex_warning:
#     748     raise ValueError(
#     749         "Complex data not supported\n{}\n".format(array)
#     750     ) from complex_warning
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:2064, in NDFrame.__array__(self, dtype)
#    2063 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2064     return np.asarray(self._values, dtype=dtype)
#
# ValueError: could not convert string to float: '2019-1118070'

# %%
from sklearn.metrics import mean_squared_error
predictions = reg.predict(X_test_poly)
mse = mean_squared_error(y_test, predictions)
print(mse)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [367], in <cell line: 3>()
#       1 from sklearn.metrics import mean_squared_error
#       2 predictions = reg.predict(X_test_poly)
# ----> 3 mse = mean_squared_error(y_test, predictions)
#       4 print(mse)
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:438, in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     378 def mean_squared_error(
#     379     y_true, y_pred, *, sample_weight=None, multioutput="uniform_average", squared=True
#     380 ):
#     381     """Mean squared error regression loss.
#     382
#     383     Read more in the :ref:`User Guide <mean_squared_error>`.
#    (...)
#     436     0.825...
#     437     """
# --> 438     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     439         y_true, y_pred, multioutput
#     440     )
#     441     check_consistent_length(y_true, y_pred, sample_weight)
#     442     output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:94, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      60 def _check_reg_targets(y_true, y_pred, multioutput, dtype="numeric"):
#      61     """Check that y_true and y_pred belong to the same regression task.
#      62
#      63     Parameters
#    (...)
#      92         the dtype argument passed to check_array.
#      93     """
# ---> 94     check_consistent_length(y_true, y_pred)
#      95     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#      96     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\validation.py:332, in check_consistent_length(*arrays)
#     330 uniques = np.unique(lengths)
#     331 if len(uniques) > 1:
# --> 332     raise ValueError(
#     333         "Found input variables with inconsistent numbers of samples: %r"
#     334         % [int(l) for l in lengths]
#     335     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [216, 211]

# %%
reg.score(X_test_poly, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [368], in <cell line: 1>()
# ----> 1 reg.score(X_test_poly, y_test)
#
# File ~\anaconda3\lib\site-packages\sklearn\base.py:706, in RegressorMixin.score(self, X, y, sample_weight)
#     703 from .metrics import r2_score
#     705 y_pred = self.predict(X)
# --> 706 return r2_score(y, y_pred, sample_weight=sample_weight)
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:789, in r2_score(y_true, y_pred, sample_weight, multioutput)
#     702 def r2_score(y_true, y_pred, *, sample_weight=None, multioutput="uniform_average"):
#     703     """:math:`R^2` (coefficient of determination) regression score function.
#     704
#     705     Best possible score is 1.0 and it can be negative (because the
#    (...)
#     787     -3.0
#     788     """
# --> 789     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     790         y_true, y_pred, multioutput
#     791     )
#     792     check_consistent_length(y_true, y_pred, sample_weight)
#     794     if _num_samples(y_pred) < 2:
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:94, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      60 def _check_reg_targets(y_true, y_pred, multioutput, dtype="numeric"):
#      61     """Check that y_true and y_pred belong to the same regression task.
#      62
#      63     Parameters
#    (...)
#      92         the dtype argument passed to check_array.
#      93     """
# ---> 94     check_consistent_length(y_true, y_pred)
#      95     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#      96     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\validation.py:332, in check_consistent_length(*arrays)
#     330 uniques = np.unique(lengths)
#     331 if len(uniques) > 1:
# --> 332     raise ValueError(
#     333         "Found input variables with inconsistent numbers of samples: %r"
#     334         % [int(l) for l in lengths]
#     335     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [216, 211]

# %%
plt.scatter(y_test, predictions)
plt.xlabel('True Values')
plt.ylabel('Predicted Values')
plt.title('Polynomial Regression Results')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2)

# %%
results = pd.DataFrame({'True Values': y_test, 'Predicted Values': predictions})

# Print the first few rows of the results
print(results)
# Out:
#       True Values  Predicted Values
# 1730     131000.0     134334.281175
# 617      165500.0     195419.534247
# 885      202000.0     133499.656565
# 2948     145000.0     150113.085364
# 896      135000.0     172612.467892
# ...           ...               ...
# 1830     100000.0     156815.646248
# 159      195000.0     167391.747028
# 879       71000.0      90336.540108
# 1895     224100.0     200258.714304
# 2488     345000.0     245981.329611
#
# [211 rows x 2 columns]

# %%
scores = cross_val_score(reg, X_test_poly, y_test, cv=5)

# %%
print(np.mean(scores))
# Out:
# 0.08247872030790196

# %%
from sklearn.metrics import mean_absolute_error

# Assume that you have already trained your model and made predictions on the test set

# Compute the MAE
mae = mean_absolute_error(y_test, predictions)

print("MAE:", mae)
# Out:
# MAE: 33506.80299721007

# %% [markdown]
# # Traitement du dataframe pour Appartement

# %%
df_app = df_app.dropna(axis=1, how='all')

# %%
missing_rate1 = df_app.isna().sum()/df_app.shape[0]
missing_rate1
# Out:
# id_mutation                     0.000000
# date_mutation                   0.000000
# numero_disposition              0.000000
# nature_mutation                 0.000000
# valeur_fonciere                 0.000000
# adresse_numero                  0.000000
# adresse_suffixe                 0.960100
# adresse_nom_voie                0.000000
# adresse_code_voie               0.000000
# code_postal                     0.000000
# code_commune                    0.000000
# nom_commune                     0.000000
# code_departement                0.000000
# id_parcelle                     0.000000
# lot1_numero                     0.428928
# lot1_surface_carrez             0.658354
# lot2_numero                     0.700748
# lot2_surface_carrez             0.932668
# lot3_numero                     0.902743
# lot3_surface_carrez             0.987531
# nombre_lots                     0.000000
# code_type_local                 0.000000
# type_local                      0.000000
# surface_reelle_bati             0.000000
# nombre_pieces_principales       0.000000
# code_nature_culture             0.571072
# nature_culture                  0.571072
# code_nature_culture_speciale    0.970075
# nature_culture_speciale         0.970075
# surface_terrain                 0.571072
# longitude                       0.000000
# latitude                        0.000000
# section_prefixe                 0.000000
# file                            0.000000
# dtype: float64

# %%
#supprimer les colonnes ayant un mesure_rate > 0.8 ainsi que les colonnes qui n'affecterons pas nos résultats
df_app = df_app.drop(columns=['file','surface_terrain','nature_culture_speciale','code_nature_culture_speciale','nature_culture','code_nature_culture','lot3_surface_carrez','lot2_surface_carrez','lot1_surface_carrez','lot1_numero','lot2_numero','lot3_numero','adresse_suffixe','code_commune','code_departement'
])

# %%
df_app.corr()
# Out:
#                            numero_disposition  valeur_fonciere  \
# numero_disposition                   1.000000        -0.032551
# valeur_fonciere                     -0.032551         1.000000
# adresse_numero                       0.072333        -0.417690
# nombre_lots                          0.001606        -0.547937
# surface_reelle_bati                 -0.006621        -0.252712
# nombre_pieces_principales           -0.000201        -0.246183
# longitude                           -0.049677         0.581622
# latitude                             0.033271        -0.463372
#
#                            adresse_numero  nombre_lots  surface_reelle_bati  \
# numero_disposition               0.072333     0.001606            -0.006621
# valeur_fonciere                 -0.417690    -0.547937            -0.252712
# adresse_numero                   1.000000     0.401999             0.367991
# nombre_lots                      0.401999     1.000000             0.384281
# surface_reelle_bati              0.367991     0.384281             1.000000
# nombre_pieces_principales        0.347589     0.418047             0.891322
# longitude                       -0.682849    -0.510475            -0.531400
# latitude                         0.473333     0.458331             0.556517
#
#                            nombre_pieces_principales  longitude  latitude
# numero_disposition                         -0.000201  -0.049677  0.033271
# valeur_fonciere                            -0.246183   0.581622 -0.463372
# adresse_numero                              0.347589  -0.682849  0.473333
# nombre_lots                                 0.418047  -0.510475  0.458331
# surface_reelle_bati                         0.891322  -0.531400  0.556517
# nombre_pieces_principales                   1.000000  -0.483104  0.461822
# longitude                                  -0.483104   1.000000 -0.816975
# latitude                                    0.461822  -0.816975  1.000000
